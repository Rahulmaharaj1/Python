# %%
Modules in Python
math
keywords
random
datetime

# %%
# math

import math

# Some common functions
print(math.sqrt(16))    # Square root → 4.0
print(math.factorial(5))  # Factorial → 120
print(math.pi)           # Constant π → 3.141592653589793
print(math.ceil(4.2))    # Round up → 5
print(math.floor(4.8))   # Round down → 4
# Out:
# 4.0
# 120
# 3.141592653589793
# 5
# 4

# %%
# keyword

import keyword

# List of all Python keywords
print(keyword.kwlist)

# Check if a word is a keyword
print(keyword.iskeyword('for'))  # True
print(keyword.iskeyword('hello'))  # False
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# True
# False

# %%
# random

import random

print(random.randint(1, 10))    # Random integer between 1 and 10
print(random.random())          # Random float between 0 and 1
print(random.choice(['apple', 'banana', 'cherry']))  # Random item from a list
my_list = [1, 2, 3, 4]
random.shuffle(my_list)         # Shuffle list in place
print(my_list)
# Out:
# 5
# 0.34184693475465633
# cherry
# [3, 2, 1, 4]

# %%
# datetime

import datetime

# Current date and time
now = datetime.datetime.now()
print(now)

# Current date only
today = datetime.date.today()
print(today)

# Creating a specific date
my_birthday = datetime.date(2000, 5, 15)
print(my_birthday)

# Time difference
future_date = datetime.date(2026, 12, 31)
delta = future_date - today
print(delta.days, "days until the future date")
# Out:
# 2026-03-08 13:21:47.750768
# 2026-03-08
# 2000-05-15
# 298 days until the future date
